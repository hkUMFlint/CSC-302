# %% [markdown]
# <a href="https://colab.research.google.com/github/hkUMFlint/CSC-302/blob/main/ICA3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
filename = '/content/drive/MyDrive/DATA/lego_setsHB.csv'
counter = 0
price = {}
difficulty = {}
with open(filename, 'r') as f1:
  next(f1)       #will help you skip first line in which we have the headers
  for line in f1:
    print(line)
    tokens = line.split(',')
    price[tokens[4]] = tokens[0]
    difficulty[tokens[4]] = tokens[5]
    counter+=1
    if counter == 1000:
      break
for key, value in price.items():
  print(key, value, difficulty[key])
# Out:
# 29.99,2,277,4,75823,Average,4.5,4
#
# 19.99,2,168,4,75822,Easy,5,4
#
# 12.99,11,74,4.3,75821,Easy,4.3,4.1
#
# 99.99,23,1032,3.6,21030,Average,4.6,4.3
#
# 79.99,14,744,3.2,21035,Challenging,4.6,4.1
#
# 59.99,7,597,3.7,21039,Average,4.9,4.4
#
# 59.99,37,598,3.7,21028,Average,4.2,4.1
#
# 49.99,24,780,4.4,21029,Average,4.7,4.3
#
# 39.99,23,468,3.6,21034,Average,4.7,4.1
#
# 39.99,11,444,3.6,21033,Average,4.8,4.5
#
# 39.99,14,386,4.1,21036,Average,4.4,3.6
#
# 34.99,53,321,3.2,21019,Average,4.6,4.4
#
# 29.99,7,361,4.2,21032,Easy,4.6,4.2
#
# 159.99,63,847,3.8,17101,Average,3.4,3.5
#
# 29.99,13,708,4.7,41597,Average,4.8,4.8
#
# 19.99,1,234,3,41614,Easy,5,5
#
# 19.99,1,160,5,41613,Very Easy,5,5
#
# 9.99,1,149,2,41609,Very Easy,3,4
#
# 9.99,1,141,2,41608,Very Easy,4,4
#
# 9.99,3,101,4,41604,Average,4.7,4.5
#
# 9.99,2,105,3,41605,Easy,5,5
#
# 9.99,1,113,5,41606,Easy,5,5
#
# 9.99,1,136,,41607,,5,
#
# 9.99,2,91,3,41485,Easy,4.5,4
#
# 9.99,7,140,3.2,40270,Easy,4.9,4.7
#
# ...
